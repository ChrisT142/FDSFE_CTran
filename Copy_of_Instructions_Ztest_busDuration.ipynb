# %% [markdown]
# <a href="https://colab.research.google.com/github/ChrisT142/FDSFE_CTran/blob/main/Copy_of_Instructions_Ztest_busDuration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trip duration for bus Septa32 is 34 min on average (+/- 2.4).
# We wonderful city planners think we have a better route that will save time.
#
# We ask you to our Department of Transportation data scientist to tell is if after we change the route has the trip duration has changed.
#
# We have measured the duration of the trips along the new route and collected the data here https://github.com/fedhere/FDSfE_FBianco/blob/main/data/triptimes.csv
#
# # What is your Null Hypothesis?

# %%
sigma = 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tripduration = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/"
"main/data/triptimes.csv", names=["duration"])

# %%
tripduration
# Out:
#      duration
# 0   31.622239
# 1   32.821376
# 2   30.229101
# 3   31.413766
# 4   39.010550
# ..        ...
# 95  26.197852
# 96  42.727410
# 97  33.731470
# 98  37.238591
# 99  36.339841
#
# [100 rows x 1 columns]

# %%
tripduration.describe()
# Out:
#          duration
# count  100.000000
# mean    34.466162
# std      7.137280
# min     16.527267
# 25%     30.020542
# 50%     34.693057
# 75%     39.603456
# max     48.749877

# %%
xbar = 34.466162

# %%
xbar = tripduration.mean()
xsigma = tripduration.std()

# %%
xbar
# Out:
# duration    34.466162
# dtype: float64

# %%
xsigma
# Out:
# duration    7.13728
# dtype: float64

# %%
import numpy as np
diff = np.abs(34 - xbar)

# %%
Z = diff/ (xsigma / np.sqrt(len(tripduration)))

# %%
Z >= sigma
# Out:
# duration    False
# dtype: bool
